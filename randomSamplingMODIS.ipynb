# %% [markdown]
# This notebook samples arctic dem product and albedo from random sampling points
#
#
# Users should change the size of spatial window when extracting the pixel values.

# %%
import geemap
import ee
import pandas as pd

# %% [markdown]
# # Prepare sample sites

# %%
Map = geemap.Map()
Map
# Out:
# Map(center=[20, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(Togg…

# %%
pd.to_datetime(1338681600000, unit="ms")
# Out:
# Timestamp('2012-06-03 00:00:00')

# %%
greenlandmask = ee.Image('OSU/GIMP/2000_ICE_OCEAN_MASK') \
                   .select('ice_mask').eq(1) #'ice_mask', 'ocean_mask'
arcticDEM = ee.Image('UMN/PGC/ArcticDEM/V3/2m_mosaic')

arcticDEMgreenland = arcticDEM.updateMask(greenlandmask)

visPara = {'min': 0,  'max': 3000.0, 'palette': ['0d13d8', '60e1ff', 'ffffff']}
# visPara = {'min': 0,  'max': 3000.0, 'palette': palette}

Map.addLayer(arcticDEMgreenland, visPara, 'Arctic DEM terrain')
Map.setCenter(-41.0, 74.0, 3)
# Map.add_colorbar(visPara, label="Elevation (m)", discrete=False, orientation="vertical", layer_name="Arctic DEM terrain")

# %%
randomPoints = ee.FeatureCollection("projects/ee-deeppurple/assets/topography/randomPoints300")
Map.addLayer(randomPoints, {}, 'Random points')
# geemap.ee_export_vector(randomPoints, 'randomPoints.kmz')

# %%
sampleN = randomPoints.size().getInfo()
sampleList = randomPoints.geometry().coordinates().getInfo()

# %% [markdown]
# ## Albedo

# %%
# https://developers.google.com/earth-engine/tutorials/community/intro-to-python-api-guiattard by https://github.com/guiattard
def ee_array_to_df(arr, list_of_bands):
    """Transforms client-side ee.Image.getRegion array to pandas.DataFrame."""
    df = pd.DataFrame(arr)

    # Rearrange the header.
    headers = df.iloc[0]
    df = pd.DataFrame(df.values[1:], columns=headers)

    # Remove rows without data inside.
    df = df[['longitude', 'latitude', 'time', *list_of_bands]]#.dropna()

    # Convert the data to numeric values.
    for band in list_of_bands:
        df[band] = pd.to_numeric(df[band], errors='coerce')

    # Convert the time field into a datetime.
    df['datetime'] = pd.to_datetime(df['time'], unit='ms')

    # Keep the columns of interest.
    df = df[['time','datetime',  *list_of_bands]]

    return df

# %%
date_start = ee.Date.fromYMD(2009, 8, 16)
date_end = ee.Date.fromYMD(2017, 3, 12)
modis = ee.ImageCollection('MODIS/006/MOD10A1').filterDate(date_start, date_end).select("Snow_Albedo_Daily_Tile")

# %%
# dem related functions
def demtool(img):
    demproduct = ee.Terrain.products(img)
    return demproduct

# %%
for i in range(sampleN):

    print('The feature id is: %d' %i)
    
    
    aoi = ee.Geometry.Point(sampleList[i])
    # Map.addLayer(aoi, {}, stationName)
    
    # arctic dem strip
    arcticdemStrip = ee.ImageCollection('UMN/PGC/ArcticDEM/V3/2m') \
                  .filterBounds(aoi) \
                  .select('elevation') \
                  .sort('system:time_start', True).map(demtool)

    pointValue = modis.getRegion(aoi, 90).getInfo() # The number e.g. 500 is the buffer size
    dfpoint = ee_array_to_df(pointValue, ["Snow_Albedo_Daily_Tile"])
    pointValueFile = 'randomPoints/modis30m/albedo/' + str(i) + '.csv'
    dfpoint.dropna().to_csv(pointValueFile, mode='w', index=False, header=True)
    
    pointValue = arcticdemStrip.getRegion(aoi, 90).getInfo()
    pointEndtime = arcticdemStrip.aggregate_array("system:time_end").getInfo()

    dfpoint = ee_array_to_df(pointValue, ['elevation', 'slope', 'aspect', 'hillshade'])
    dfpoint["time_end"] = pointEndtime
    pointValueFile = 'randomPoints/modis30m/dem/' + str(i) + '.csv'
    dfpoint.dropna().to_csv(pointValueFile, mode='w', index=False, header=True)
# Out:
# The feature id is: 0
# The feature id is: 1
# The feature id is: 2
# The feature id is: 3
# The feature id is: 4
# The feature id is: 5
# The feature id is: 6
# The feature id is: 7
# The feature id is: 8
# The feature id is: 9
# The feature id is: 10
# The feature id is: 11
# The feature id is: 12
# The feature id is: 13
# The feature id is: 14
# The feature id is: 15
# The feature id is: 16
# The feature id is: 17
# The feature id is: 18
# The feature id is: 19
# The feature id is: 20
# The feature id is: 21
# The feature id is: 22
# The feature id is: 23
# The feature id is: 24
# The feature id is: 25
# The feature id is: 26
# The feature id is: 27
# The feature id is: 28
# The feature id is: 29
# The feature id is: 30
# The feature id is: 31
# The feature id is: 32
# The feature id is: 33
# The feature id is: 34
# The feature id is: 35
# The feature id is: 36
# The feature id is: 37
# The feature id is: 38
# The feature id is: 39
# The feature id is: 40
# The feature id is: 41
# The feature id is: 42
# The feature id is: 43
# The feature id is: 44
# The feature id is: 45
# The feature id is: 46
# The feature id is: 47
# The feature id is: 48
# The feature id is: 49
# The feature id is: 50
# The feature id is: 51
# The feature id is: 52
# The feature id is: 53
# The feature id is: 54
# The feature id is: 55
# The feature id is: 56
# The feature id is: 57
# The feature id is: 58
# The feature id is: 59
# The feature id is: 60
# The feature id is: 61
# The feature id is: 62
# The feature id is: 63
# The feature id is: 64
# The feature id is: 65
# The feature id is: 66
# The feature id is: 67
# The feature id is: 68
# The feature id is: 69
# The feature id is: 70
# The feature id is: 71
# The feature id is: 72
# The feature id is: 73
# The feature id is: 74
# The feature id is: 75
# The feature id is: 76
# The feature id is: 77
# The feature id is: 78
# The feature id is: 79
# The feature id is: 80
# The feature id is: 81
# The feature id is: 82
# The feature id is: 83
# The feature id is: 84
# The feature id is: 85
# The feature id is: 86
# The feature id is: 87
# The feature id is: 88
# The feature id is: 89
# The feature id is: 90
# The feature id is: 91
# The feature id is: 92
# The feature id is: 93
# The feature id is: 94
# The feature id is: 95
# The feature id is: 96
# The feature id is: 97
# The feature id is: 98
# The feature id is: 99
# The feature id is: 100
# The feature id is: 101
# The feature id is: 102
# The feature id is: 103
# The feature id is: 104
# The feature id is: 105
# The feature id is: 106
# The feature id is: 107
# The feature id is: 108
# The feature id is: 109
# The feature id is: 110
# The feature id is: 111
# The feature id is: 112
# The feature id is: 113
# The feature id is: 114
# The feature id is: 115
# The feature id is: 116
# The feature id is: 117
# The feature id is: 118
# The feature id is: 119
# The feature id is: 120
# The feature id is: 121
# The feature id is: 122
# The feature id is: 123
# The feature id is: 124
# The feature id is: 125
# The feature id is: 126
# The feature id is: 127
# The feature id is: 128
# The feature id is: 129
# The feature id is: 130
# The feature id is: 131
# The feature id is: 132
# The feature id is: 133
# The feature id is: 134
# The feature id is: 135
# The feature id is: 136
# The feature id is: 137
# The feature id is: 138
# The feature id is: 139
# The feature id is: 140
# The feature id is: 141
# The feature id is: 142
# The feature id is: 143
# The feature id is: 144
# The feature id is: 145
# The feature id is: 146
# The feature id is: 147
# The feature id is: 148
# The feature id is: 149
# The feature id is: 150
# The feature id is: 151
# The feature id is: 152
# The feature id is: 153
# The feature id is: 154
# The feature id is: 155
# The feature id is: 156
# The feature id is: 157
# The feature id is: 158
# The feature id is: 159
# The feature id is: 160
# The feature id is: 161
# The feature id is: 162
# The feature id is: 163
# The feature id is: 164
# The feature id is: 165
# The feature id is: 166
# The feature id is: 167
# The feature id is: 168
# The feature id is: 169
# The feature id is: 170
# The feature id is: 171
# The feature id is: 172
# The feature id is: 173
# The feature id is: 174
# The feature id is: 175
# The feature id is: 176
# The feature id is: 177
# The feature id is: 178
# The feature id is: 179
# The feature id is: 180
# The feature id is: 181
# The feature id is: 182
# The feature id is: 183
# The feature id is: 184
# The feature id is: 185
# The feature id is: 186
# The feature id is: 187
# The feature id is: 188
# The feature id is: 189
# The feature id is: 190
# The feature id is: 191
# The feature id is: 192
# The feature id is: 193
# The feature id is: 194
# The feature id is: 195
# The feature id is: 196
# The feature id is: 197
# The feature id is: 198
# The feature id is: 199
# The feature id is: 200
# The feature id is: 201
# The feature id is: 202
# The feature id is: 203
# The feature id is: 204
# The feature id is: 205
# The feature id is: 206
# The feature id is: 207
# The feature id is: 208
# The feature id is: 209
# The feature id is: 210
# The feature id is: 211
# The feature id is: 212
# The feature id is: 213
# The feature id is: 214
# The feature id is: 215
# The feature id is: 216
# The feature id is: 217
# The feature id is: 218
# The feature id is: 219
# The feature id is: 220
# The feature id is: 221
# The feature id is: 222
# The feature id is: 223
# The feature id is: 224
# The feature id is: 225
# The feature id is: 226
# The feature id is: 227
# The feature id is: 228
# The feature id is: 229
# The feature id is: 230
# The feature id is: 231
# The feature id is: 232
# The feature id is: 233
# The feature id is: 234
# The feature id is: 235
# The feature id is: 236
# The feature id is: 237
# The feature id is: 238
# The feature id is: 239
# The feature id is: 240
# The feature id is: 241
# The feature id is: 242
# The feature id is: 243
# The feature id is: 244
# The feature id is: 245
# The feature id is: 246
# The feature id is: 247
# The feature id is: 248
# The feature id is: 249
# The feature id is: 250
# The feature id is: 251
# The feature id is: 252
# The feature id is: 253
# The feature id is: 254
# The feature id is: 255
# The feature id is: 256
# The feature id is: 257
# The feature id is: 258
# The feature id is: 259
# The feature id is: 260
# The feature id is: 261
# The feature id is: 262
# The feature id is: 263
# The feature id is: 264
# The feature id is: 265
# The feature id is: 266
# The feature id is: 267
# The feature id is: 268
# The feature id is: 269
# The feature id is: 270
# The feature id is: 271
# The feature id is: 272
# The feature id is: 273
# The feature id is: 274
# The feature id is: 275
# The feature id is: 276
# The feature id is: 277
# The feature id is: 278
# The feature id is: 279
# The feature id is: 280
# The feature id is: 281
# The feature id is: 282
# The feature id is: 283
# The feature id is: 284
# The feature id is: 285
# The feature id is: 286
# The feature id is: 287
# The feature id is: 288
# The feature id is: 289
# The feature id is: 290
# The feature id is: 291
# The feature id is: 292
# The feature id is: 293
# The feature id is: 294
# The feature id is: 295
# The feature id is: 296
# The feature id is: 297
# The feature id is: 298
# The feature id is: 299
